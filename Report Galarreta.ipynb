# %% [markdown]
# # Final Report | Capstone Project

# %% [markdown]
# # Introduction

# %% [markdown]
# The purpose of my project is to help people in exploring better facilities around their neighborhood. The idea is to select a great neighborhood out of numbers of other neighborhoods in Downtown Toronto.
# I want to help people decide which is the best place to live, considering factors such as nearby places to eat, schools, etc. It is ideal for people who want to feel safe before making the decision to move.

# %% [markdown]
# # Data section

# %% [markdown]
# Data Link: https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M
#
# I will use Downtown Toronto dataset which we scrapped from wikipedia. Dataset consisting of latitude and longitude, zip codes.
#
# I will also use Foursquare and the information i will obtain is: Neighborhood, Neighborhood Latitude, Neighborhood Longitude, Venue, Name of the venue, Venue Latitude, Venue Longitude and Venue Category.

# %% [markdown]
# # Metholody section

# %% [markdown]
# Using K-Means Clustering Approach

# %% [markdown]
# https://github.com/laugalarreta/IBMLAUGALARRETA/blob/master/K%20means%20Clustering.png

# %% [markdown]
# Most Common venues near

# %% [markdown]
# https://github.com/laugalarreta/IBMLAUGALARRETA/blob/master/Most%20common%20venues%20near.png

# %% [markdown]
# # Results Section

# %% [markdown]
# Map

# %% [markdown]
# https://github.com/laugalarreta/IBMLAUGALARRETA/blob/master/Map.png

# %% [markdown]
# Average housing price

# %% [markdown]
# https://github.com/laugalarreta/IBMLAUGALARRETA/blob/master/Average%20housing%20prices.png

# %% [markdown]
# # Discussion section

# %% [markdown]
# Problem Which Tried to Solve:

# %% [markdown]
# The purpose of my project is to help people in exploring better facilities around their neighborhood. The idea is to select a great neighborhood out of numbers of other neighborhoods in Downtown Toronto.
